# %% [markdown]
# # Codebook for 明实录

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import multivariate_normal, norm, uniform
import scipy.integrate as integrate
from ipywidgets import interact, interactive
import seaborn as sns
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm
import pickle
import time

from urllib.request import urlopen 
import re
def read_url(url): 
    return re.sub('\\s+', ' ', urlopen(url).read().decode())

# %% [markdown]
# ## Import 明实录

# %%
with open("datasets/明实录.txt", "r") as f:
    mingshilu = f.read()

# %% [markdown]
# ## Finding countries that did tributes, order by number of times

# %%
pattern = r"\S+[国卫]\S{0,6}遣"
matched = re.findall(pattern, mingshilu)
#matched

## Question: identify more places (like the way with 卫 and southwest 土司)
## figure out what are the most frequent words in the place of 国 (something like 司)

# %%
country_extract = r"\S+[国卫]"
matched_country = []
for i in matched:
    matched_country.append(re.findall(country_extract, i))
matched_country = [x for x in matched_country for x in x]

#all country names from 明史
enhanced_country = []
for i in [re.findall(r'福余|泰宁|灌顶|佛菻|渤利|巴里|西洋|阇婆|苏禄|耽罗|大理|哈密|尼八剌|娑罗|高丽|朝鲜|安南|日本|琉球|吕宋|合猫里|美洛居|沙瑶呐哔啴|鸡笼|婆罗|麻叶瓮|古麻|剌朗|冯嘉施兰|文郎马神|占城|真腊|暹罗|爪哇|三佛齐|浡泥|满剌加|苏门答剌|须文达那|苏禄|西洋琐里|琐里|览邦|淡巴|百花|彭亨|那孤儿|黎伐|南渤利|阿鲁|柔佛|丁机宜|巴喇西|佛郎机|和兰|古里|柯枝|葛兰|锡兰山|榜葛剌|沼纳朴儿|祖法儿|木骨都束|不剌哇|竹步|阿丹|剌撒|麻林|忽鲁谟斯|溜山|南巫里|加异勒|甘巴里|急兰丹|沙里湾泥|底里|千里达|失剌比|古里班卒|剌泥|葛达|拂菻|意大里亚|鞑靼|瓦剌|朵颜',
         i) for i in matched_country]:
    if i !=[]:
        for j in np.arange(len(i)):
            enhanced_country.append(i[j])

matched_country_df = pd.DataFrame(data = {'Country': enhanced_country})
sorted_country = pd.DataFrame({'Country':matched_country_df.groupby('Country', as_index = False).size().sort_values(ascending = False)})
sorted_country
# Out:
#          Country
# Country
# 朝鲜           635
# 琉球           242
# 占城           135
# 安南           116
# 泰宁            91
# 朵颜            70
# 爪哇            66
# 暹罗            58
# 高丽            41
# 福余            37
# 日本            36
# 哈密            33
# 满剌加           30
# 灌顶            26
# 真腊            16
# 苏门答剌          12
# 瓦剌            11
# 大理            10
# 三佛齐            9
# 西洋             9
# 榜葛剌            8
# 浡泥             6
# 阿鲁             5
# 古里             5
# 渤利             5
# 锡兰山            4
# 忽鲁谟斯           4
# 柯枝             3
# 剌撒             3
# 加异勒            3
# 阿丹             3
# 溜山             2
# 尼八剌            2
# 不剌哇            2
# 祖法儿            2
# 娑罗             2
# 鞑靼             2
# 琐里             2
# 巴里             2
# 甘巴里            2
# 苏禄             2
# 彭亨             1
# 婆罗             1
# 阇婆             1
# 淡巴             1
# 古麻             1
# 葛达             1
# 百花             1
# 葛兰             1
# 木骨都束           1
# 佛菻             1
# 耽罗             1

# %%
## Question
# group by country by region (i.e. Southeast Asia)
# Table: find longtitude and latitude for country's capitals, with number of tributes, perhaps region as category

## below 23 latitude --> South China Sea

#sorted_country.to_csv('sorted_country.csv')
sorted_country = pd.read_csv('with_location.csv')

# %%
def region_f(latitude, longtitude):
    if latitude <= 22.5 and longtitude >= 101:
        return 'southeast'
    if latitude >= 22.5 and longtitude >= 120: 
        return 'east'
    if latitude >= 30 and longtitude >= 90: 
        return 'north'
    if longtitude <= 101 and longtitude >= 90 and latitude <= 30:
        return 'southwest'
    if longtitude < 90:
        return 'west'

# %%
region = [region_f(sorted_country.iloc[i]['latitude'], sorted_country.iloc[i]['longitude']) for i in np.arange(len(sorted_country))]
sorted_country['region'] = region
sorted_country.sort_values(['count'], ascending = False)

#find more northern places without 国 (something like 卫)
# Out:
#    Country  count       capital   latitude   longitude     region
# 47      朝鲜    631            王京  37.566536  126.977966       east
# 48      琉球    242            首里  26.216836  127.715699       east
# 37      占城    134          僧伽补罗  11.573355  108.989695  southeast
# 35      安南    116            河内  21.035847  105.807735  southeast
# 39      爪哇     66          满者伯夷  -7.542012  112.390994  southeast
# 28      暹罗     58          阿瑜陀耶  14.364116  100.544505  southwest
# 46      高丽     41            开京  37.959859  126.613430       east
# 49      日本     36            京都  35.011635  135.768036       east
# 29     满剌加     30           马六甲   2.230183  102.221541  southeast
# 21      灌顶     26           烈伍栋  29.225461   91.761971  southwest
# 34      真腊     16          伊奢那城  12.871247  105.045358  southeast
# 26    苏门答剌     12            八昔   3.595450   98.683346  southwest
# 23      哈密     10            哈密  42.874296   93.537216      north
# 33     三佛齐      9            巨港  -2.975195  104.773605  southeast
# 22     榜葛剌      8           茶那咭  22.335000   91.832500  southwest
# 27      大理      7           大理城  25.608517  100.267872  southwest
# 40      浡泥      6           渤泥城   4.529864  114.640761  southeast
# 13      西洋      6           滕卡西   8.970000   77.320000       west
# 24      渤利      5          班达亚齐   5.557093   95.316301  southwest
# 25      阿鲁      5  Kota Rentang   3.709512   98.600437  southwest
# 10      古里      5          科泽科德  11.150000   75.460000       west
# 20      瓦剌      4           阿尔泰  49.194047   89.076982       west
# 17     锡兰山      4           甘波罗   7.164892   80.576667       west
# 8     忽鲁谟斯      4          霍尔木兹  27.095000   56.452778       west
# 16     加异勒      3           加异勒   8.396872   78.058682       west
# 4       阿丹      3            亚丁  12.800000   45.033333       west
# 11      柯枝      3            戈奇   9.970000   76.280000       west
# 42      朵颜      3          翁牛特旗  42.933333  119.033333      north
# 9       溜山      2          马尔代夫  -0.607753   73.094758       west
# 2      不剌哇      2           巴拉韦   1.113333   44.030278       west
# 43      苏禄      2           霍洛岛   6.026449  120.961413  southeast
# 6       剌撒      2           木卡拉  14.540903   49.126950       west
# 19     尼八剌      2          加德满都  27.720000   85.370000       west
# 7      祖法儿      2           祖法儿  17.010045   54.134612       west
# 18      娑罗      2            娑罗  26.739170   83.890660       west
# 14     甘巴里      2          科摩林角   8.084000   77.546000       west
# 15      琐里      2        蒂鲁内尔维利   8.722558   77.757782       west
# 0       巴里      2            巴里  41.125300   16.866700       west
# 32      彭亨      1            关丹   3.820000  103.330000  southeast
# 36      百花      1          巴查查兰  -6.925941  107.773979  southeast
# 1       佛菻      1         君士坦丁堡  41.020526   28.981933       west
# 38      阇婆      1            阇婆  -6.962452  110.289434  southeast
# 31      鞑靼      1          哈拉和林  47.210278  102.847778      north
# 5     木骨都束      1          摩加迪沙   2.033333   45.333333       west
# 41      婆罗      1        斯里巴加湾市   4.890283  114.942217  southeast
# 30      淡巴      1            淡巴   3.035449  102.721410  southeast
# 12      葛兰      1            葛兰   8.880000   76.600000       west
# 44      古麻      1            古麻   8.000000  125.000000  southeast
# 45      耽罗      1           济州城  33.499823  126.531296       east
# 3       葛达      1           巴格达  33.320788   44.364135       west

# %% [markdown]
# ## Finding year and month for each tributary mission

# %%
month_extract = r"卷[之]?[一二三四五六七八九十百]+[）]?[上下]?\s+\S+[正一二三四五六七八九十]{1,2}月"
matched_month = re.findall(month_extract, mingshilu)

#cleared year and month

month_by_emperor = []
for i in matched_month:
    x = re.findall(r"((洪武|建文|永乐|洪熙|宣德|正统|景泰|天顺|成化|弘治|正德|嘉靖|隆庆|万历|泰昌|天启)(\S{0,4}年\S{0,4}月))", i)
    if x != []:
        month_by_emperor.append(x[0][0])
#month_by_emperor

# %%
month_extract = r'((洪武|建文|永乐|洪熙|宣德|正统|景泰|天顺|成化|弘治|正德|嘉靖|隆庆|万历|泰昌|天启)(\S{0,4}年)(\S{0,4}月))|(\S{0,5}国\S{0,6}遣)'
matched_month = re.findall(month_extract, mingshilu)
matched_month[0:10]
# Out:
# [('永乐十六年五月', '永乐', '十六年', '五月', ''),
#  ('永乐十六年五月', '永乐', '十六年', '五月', ''),
#  ('永乐元年六月', '永乐', '元年', '六月', ''),
#  ('永乐元年六月', '永乐', '元年', '六月', ''),
#  ('永乐元年六月', '永乐', '元年', '六月', ''),
#  ('永乐元年六月', '永乐', '元年', '六月', ''),
#  ('永乐元年六月', '永乐', '元年', '六月', ''),
#  ('永乐元年六月', '永乐', '元年', '六月', ''),
#  ('', '', '', '', '○乙卯方国珍遣'),
#  ('', '', '', '', '俾见天日此国珍所素愿也谨遣')]

# %%
## Match tributes with month/year 

## use an iterator to record the last month and the last tribute 

final = []
date = ['洪武元年春正月', '洪武', '元年', '春正月']
for i in matched_month:
    if i[0] != '' and re.findall(r'[正一二三四五六七八九十]{1,2}月', i[3]) != []:
        date = [i[0], i[1], i[2], i[3]]
    if i[4] != '':
        _country = re.findall(r'灌顶|佛菻|渤利|巴里|西洋|阇婆|苏禄|耽罗|大理|哈密|尼八剌|娑罗|高丽|朝鲜|安南|日本|琉球|吕宋|合猫里|美洛居|沙瑶呐哔啴|鸡笼|婆罗|麻叶瓮|古麻|剌朗|冯嘉施兰|文郎马神|占城|真腊|暹罗|爪哇|三佛齐|浡泥|满剌加|苏门答剌|须文达那|苏禄|西洋琐里|琐里|览邦|淡巴|百花|彭亨|那孤儿|黎伐|南渤利|阿鲁|柔佛|丁机宜|巴喇西|佛郎机|和兰|古里|柯枝|葛兰|锡兰山|榜葛剌|沼纳朴儿|祖法儿|木骨都束|不剌哇|竹步|阿丹|剌撒|麻林|忽鲁谟斯|溜山|南巫里|加异勒|甘巴里|急兰丹|沙里湾泥|底里|千里达|失剌比|古里班卒|剌泥|葛达|拂菻|意大里亚|鞑靼|瓦剌|朵颜', i[4])
        if _country != []:
            final.append([_country[0], date])

# %%
## Question
# Do it by decade
# or divide the tributes by the number of years an emperor reigns

## which countries send the most by month

# %%
## deliverable
### a table with country, coming/going, year, month

country_col = []
emperor_col = []
year_col = []
month_col = []
for i in final:
    country_col.append(i[0])
    emperor_col.append(i[1][1])
    year_col.append(i[1][2])
    month_col.append(re.findall(r'[正一二三四五六七八九十]{1,2}月',i[1][3])[0])

final_df = pd.DataFrame(data = {'Country': country_col, 'Emperor': emperor_col, 'Year': year_col, 'Month': month_col})

# %%
def helper(emperor):
    if emperor == '洪武':
        return 1
    if emperor == '建文':
        return 2
    if emperor == '永乐':
        return 3
    if emperor == '洪熙':
        return 4
    if emperor == '宣德':
        return 5
    if emperor == '正统':
        return 6
    if emperor == '景泰':
        return 7
    if emperor == '天顺':
        return 8
    if emperor == '成化':
        return 9
    if emperor == '弘治':
        return 10
    if emperor == '正德':
        return 11
    if emperor == '嘉靖':
        return 12
    if emperor == '隆庆':
        return 13
    if emperor == '万历':
        return 14
    if emperor == '泰昌':
        return 15
    if emperor == '天启':
        return 16

def helper1(emperor):
    if emperor == '洪武':
        return 31
    if emperor == '建文':
        return 5
    if emperor == '永乐':
        return 23
    if emperor == '洪熙':
        return 2
    if emperor == '宣德':
        return 11
    if emperor == '正统':
        return 15
    if emperor == '景泰':
        return 9
    if emperor == '天顺':
        return 8
    if emperor == '成化':
        return 24
    if emperor == '弘治':
        return 19
    if emperor == '正德':
        return 17
    if emperor == '嘉靖':
        return 47
    if emperor == '隆庆':
        return 6
    if emperor == '万历':
        return 49
    if emperor == '泰昌':
        return 1
    if emperor == '天启':
        return 8

# %%
final_df['Emperor Order'] = [helper(x) for x in final_df['Emperor']]
final_df['Reign Years'] = [helper1(x) for x in final_df['Emperor']]
#final_df
final_df_region = final_df.merge(sorted_country[['Country', 'capital', 'latitude', 'longitude', 'region']], on ='Country')
final_df_region
# Out:
#      Country Emperor  Year Month  Emperor Order  Reign Years capital  \
# 0         占城      洪武    二年    二月              1           31    僧伽补罗
# 1         占城      洪武    二年    九月              1           31    僧伽补罗
# 2         占城      洪武    三年    八月              1           31    僧伽补罗
# 3         占城      洪武    四年    七月              1           31    僧伽补罗
# 4         占城      洪武    五年    九月              1           31    僧伽补罗
# ...      ...     ...   ...   ...            ...          ...     ...
# 1239     加异勒      宣德    八年    八月              5           11     加异勒
# 1240     锡兰山      正统    十年    二月              6           15     甘波罗
# 1241    苏门答剌      天顺    七年    七月              8            8      八昔
# 1242    苏门答剌      成化   十六年    八月              9           24      八昔
# 1243    苏门答剌      成化  二十二年    六月              9           24      八昔
#
#        latitude   longitude     region
# 0     11.573355  108.989695  southeast
# 1     11.573355  108.989695  southeast
# 2     11.573355  108.989695  southeast
# 3     11.573355  108.989695  southeast
# 4     11.573355  108.989695  southeast
# ...         ...         ...        ...
# 1239   8.396872   78.058682  southwest
# 1240   7.164892   80.576667  southwest
# 1241   3.595450   98.683346  southeast
# 1242   3.595450   98.683346  southeast
# 1243   3.595450   98.683346  southeast
#
# [1244 rows x 10 columns]

# %%
#final_df.to_csv('final.csv')

# %% [markdown]
# ## Graphs

# %%
by_country_emperor = final_df.groupby(['Country', 'Emperor', 'Emperor Order', 'Reign Years']).size().to_frame('count').reset_index()
by_country_emperor['count density'] = by_country_emperor['count'] / by_country_emperor['Reign Years']
chaoxian = by_country_emperor[by_country_emperor['Country'] == '琉球'].sort_values('Emperor Order')

plt.rcParams['font.family'] = ['Heiti TC']

plt.bar(chaoxian['Emperor'], chaoxian['count density'])
plt.title('分朝代朝贡图')
# Out:
# Text(0.5, 1.0, '分朝代朝贡图')

# %%
by_region_emperor = final_df_region.groupby(['region', 'Emperor', 'Emperor Order', 'Reign Years']).size().to_frame('count').reset_index()
by_region_emperor['count density'] = by_region_emperor['count'] / by_region_emperor['Reign Years']
location = by_region_emperor[by_region_emperor['region'] == 'north'].sort_values('Emperor Order')

plt.rcParams['font.family'] = ['Heiti TC']

plt.bar(location['Emperor'], location['count density'])
plt.title('分朝代朝贡图')
# Out:
# Text(0.5, 1.0, '分朝代朝贡图')

# %%
final_df_region[final_df_region['region'] == 'west']
# Out:
#      Country Emperor Year Month  Emperor Order  Reign Years capital  \
# 1231      巴里      永乐  十九年    正月              3           23      巴里
# 1235      葛达      宣德   元年    五月              5           11     巴格达
# 1238    忽鲁谟斯      宣德   八年    八月              5           11    霍尔木兹
#
#        latitude  longitude region
# 1231  41.125300  16.866700   west
# 1235  33.320788  44.364135   west
# 1238  27.095000  56.452778   west

# %%
#figuring it out: is it the country coming to Ming, or the other way around

# %%
##Bonus
#On the lookout for typos
#finding dates by matching 天干地支 with number

# %%
## Check how many times a country show up without the word 国
## Check with those tributes with mentions over 4

country_without = r"琉球[^遣○]{16,45}遣"
matched = re.findall(country_without, mingshilu)
#len(matched)
